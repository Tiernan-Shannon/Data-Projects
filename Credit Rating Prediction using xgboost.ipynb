# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
file = 'German.xlsx'

# %%
data = pd.read_excel(file)

# %%
data.head(4)
# Out:
#   Checking Account Status  Duration in month Credit History Purpose  \
# 0                     A11                  6            A34     A43
# 1                     A12                 48            A32     A43
# 2                     A14                 12            A34     A46
# 3                     A11                 42            A32     A42
#
#    Credit Amount Savings Account/Bonds Present Employment since  \
# 0           1169                   A65                      A75
# 1           5951                   A61                      A73
# 2           2096                   A61                      A74
# 3           7882                   A61                      A74
#
#    Installment rate in % of disposable income Personal Status Other debtors  \
# 0                                           4             A93          A101
# 1                                           2             A92          A101
# 2                                           2             A93          A101
# 3                                           2             A93          A103
#
#        ...       Property Age  Other installment plans Housing  \
# 0      ...           A121  67                     A143    A152
# 1      ...           A121  22                     A143    A152
# 2      ...           A121  49                     A143    A152
# 3      ...           A122  45                     A143    A153
#
#   Number of existing credits  Job type Number of dependents  Telephone  \
# 0                          2      A173                    1       A192
# 1                          1      A173                    1       A191
# 2                          1      A172                    2       A191
# 3                          1      A173                    2       A191
#
#   Foreign worker Credit Rating
# 0           A201             1
# 1           A201             2
# 2           A201             1
# 3           A201             1
#
# [4 rows x 21 columns]

# %%
# checking the column names and data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# Checking Account Status                       1000 non-null object
# Duration in month                             1000 non-null int64
# Credit History                                1000 non-null object
# Purpose                                       1000 non-null object
# Credit Amount                                 1000 non-null int64
# Savings Account/Bonds                         1000 non-null object
# Present Employment since                      1000 non-null object
# Installment rate in % of disposable income    1000 non-null int64
# Personal Status                               1000 non-null object
# Other debtors                                 1000 non-null object
# Present residence since                       1000 non-null int64
# Property                                      1000 non-null object
# Age                                           1000 non-null int64
# Other installment plans                       1000 non-null object
# Housing                                       1000 non-null object
# Number of existing credits                    1000 non-null int64
# Job type                                      1000 non-null object
# Number of dependents                          1000 non-null int64
# Telephone                                     1000 non-null object
# Foreign worker                                1000 non-null object
# Credit Rating                                 1000 non-null int64
# dtypes: int64(8), object(13)
# memory usage: 164.1+ KB

# %%
# we can see that a number of our columns contain text while the remainder are numeric

# %%
# Checking for null values

# %%
data.isnull().sum()
# Out:
# Checking Account Status                       0
# Duration in month                             0
# Credit History                                0
# Purpose                                       0
# Credit Amount                                 0
# Savings Account/Bonds                         0
# Present Employment since                      0
# Installment rate in % of disposable income    0
# Personal Status                               0
# Other debtors                                 0
# Present residence since                       0
# Property                                      0
# Age                                           0
# Other installment plans                       0
# Housing                                       0
# Number of existing credits                    0
# Job type                                      0
# Number of dependents                          0
# Telephone                                     0
# Foreign worker                                0
# Credit Rating                                 0
# dtype: int64

# %% [markdown]
# # Exploring object data

# %%
# getting list of object columns

# %%
listo = data.select_dtypes(['object']).columns
print(listo)
# Out:
# Index(['Checking Account Status', 'Credit History', 'Purpose',
#        'Savings Account/Bonds', 'Present Employment since', 'Personal Status',
#        'Other debtors', 'Property', 'Other installment plans', 'Housing',
#        'Job type', 'Telephone', 'Foreign worker'],
#       dtype='object')

# %%
#plotting object data
# using countplots to view each variable by class frequency

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (15,15))

# %%
ax1 = sns.countplot(data["Credit History"],ax = axes[0,0])
for p in ax1.patches:
    height = p.get_height()
    ax1.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax2 = sns.countplot(data["Checking Account Status"],ax = axes[0,1])
for p in ax2.patches:
    height = p.get_height()
    ax2.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax3 = sns.countplot(data["Purpose"],ax = axes[1,0])
for p in ax3.patches:
    height = p.get_height()
    ax3.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax4 = sns.countplot(data["Savings Account/Bonds"],ax = axes[1,1])
for p in ax4.patches:
    height = p.get_height()
    ax4.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (15,15))

# %%
ax6 = sns.countplot(data["Present Employment since"],ax = axes[0,0])
for p in ax6.patches:
    height = p.get_height()
    ax6.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax7 = sns.countplot(data["Personal Status"],ax = axes[0,1])
for p in ax7.patches:
    height = p.get_height()
    ax7.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax8 = sns.countplot(data["Property"],ax = axes[1,0])
for p in ax8.patches:
    height = p.get_height()
    ax8.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax9 = sns.countplot(data["Other installment plans"],ax = axes[1,1])
for p in ax9.patches:
    height = p.get_height()
    ax9.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (15,15))

# %%
ax2 = sns.countplot(data["Housing"],ax = axes[0,0])
for p in ax2.patches:
    height = p.get_height()
    ax2.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax2 = sns.countplot(data["Job type"],ax = axes[0,1])
for p in ax2.patches:
    height = p.get_height()
    ax2.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
ax2 = sns.countplot(data["Foreign worker"],ax = axes[1,0])
for p in ax2.patches:
    height = p.get_height()
    ax2.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center")
plt.show()

# %%
my_tab = pd.crosstab(index=data["Credit History"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab1 = pd.crosstab(index=data["Checking Account Status"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab2 = pd.crosstab(index=data["Purpose"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab3 = pd.crosstab(index=data["Purpose"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab4 = pd.crosstab(index=data["Present Employment since"],  # Make a crosstab
                              columns="count") 

my_tab5 = pd.crosstab(index=data["Personal Status"],  # Make a crosstab
                              columns="count") 
my_tab6 = pd.crosstab(index=data["Other debtors"],  # Make a crosstab
                              columns="count") 
my_tab7 = pd.crosstab(index=data["Property"],  # Make a crosstab
                              columns="count") 
my_tab8 = pd.crosstab(index=data["Other installment plans"],  # Make a crosstab
                              columns="count") 
my_tab9 = pd.crosstab(index=data["Housing"],  # Make a crosstab
                              columns="count") 
my_tab10 = pd.crosstab(index=data["Job type"],  # Make a crosstab
                              columns="count") 
my_tab11 = pd.crosstab(index=data["Foreign worker"],  # Make a crosstab
                              columns="count")

# %% [markdown]
# # Exploring Numerical Data

# %%
# Listing numerical variables

# %%
data1 = data.select_dtypes(['float64','int64']).columns

# %%
data2 = data[data1]

# %%
# descriptive statistics for numeric data

# %%
data2.describe()
# Out:
#        Duration in month  Credit Amount  \
# count        1000.000000    1000.000000
# mean           20.903000    3271.258000
# std            12.058814    2822.736876
# min             4.000000     250.000000
# 25%            12.000000    1365.500000
# 50%            18.000000    2319.500000
# 75%            24.000000    3972.250000
# max            72.000000   18424.000000
#
#        Installment rate in % of disposable income  Present residence since  \
# count                                 1000.000000              1000.000000
# mean                                     2.973000                 2.845000
# std                                      1.118715                 1.103718
# min                                      1.000000                 1.000000
# 25%                                      2.000000                 2.000000
# 50%                                      3.000000                 3.000000
# 75%                                      4.000000                 4.000000
# max                                      4.000000                 4.000000
#
#                Age  Number of existing credits  Number of dependents  \
# count  1000.000000                 1000.000000           1000.000000
# mean     35.546000                    1.407000              1.155000
# std      11.375469                    0.577654              0.362086
# min      19.000000                    1.000000              1.000000
# 25%      27.000000                    1.000000              1.000000
# 50%      33.000000                    1.000000              1.000000
# 75%      42.000000                    2.000000              1.000000
# max      75.000000                    4.000000              2.000000
#
#        Credit Rating
# count    1000.000000
# mean        1.300000
# std         0.458487
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000

# %%
# numeric correlations

# %%
data2.corr()
# Out:
#                                             Duration in month  Credit Amount  \
# Duration in month                                    1.000000       0.624984
# Credit Amount                                        0.624984       1.000000
# Installment rate in % of disposable income           0.074749      -0.271316
# Present residence since                              0.034067       0.028926
# Age                                                 -0.036136       0.032716
# Number of existing credits                          -0.011284       0.020795
# Number of dependents                                -0.023834       0.017142
# Credit Rating                                        0.214927       0.154739
#
#                                             Installment rate in % of disposable income  \
# Duration in month                                                             0.074749
# Credit Amount                                                                -0.271316
# Installment rate in % of disposable income                                    1.000000
# Present residence since                                                       0.049302
# Age                                                                           0.058266
# Number of existing credits                                                    0.021669
# Number of dependents                                                         -0.071207
# Credit Rating                                                                 0.072404
#
#                                             Present residence since       Age  \
# Duration in month                                          0.034067 -0.036136
# Credit Amount                                              0.028926  0.032716
# Installment rate in % of disposable income                 0.049302  0.058266
# Present residence since                                    1.000000  0.266419
# Age                                                        0.266419  1.000000
# Number of existing credits                                 0.089625  0.149254
# Number of dependents                                       0.042643  0.118201
# Credit Rating                                              0.002967 -0.091127
#
#                                             Number of existing credits  \
# Duration in month                                            -0.011284
# Credit Amount                                                 0.020795
# Installment rate in % of disposable income                    0.021669
# Present residence since                                       0.089625
# Age                                                           0.149254
# Number of existing credits                                    1.000000
# Number of dependents                                          0.109667
# Credit Rating                                                -0.045732
#
#                                             Number of dependents  \
# Duration in month                                      -0.023834
# Credit Amount                                           0.017142
# Installment rate in % of disposable income             -0.071207
# Present residence since                                 0.042643
# Age                                                     0.118201
# Number of existing credits                              0.109667
# Number of dependents                                    1.000000
# Credit Rating                                          -0.003015
#
#                                             Credit Rating
# Duration in month                                0.214927
# Credit Amount                                    0.154739
# Installment rate in % of disposable income       0.072404
# Present residence since                          0.002967
# Age                                             -0.091127
# Number of existing credits                      -0.045732
# Number of dependents                            -0.003015
# Credit Rating                                    1.000000

# %%
sns.heatmap(data2.corr(),annot=True, fmt=".2f")
plt.show()

# %%
sns.pairplot(data2)
plt.show()

# %%
# not surprising linear relationship between duration of loan and amount
# the majority of data is categorical

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (30,30))

# %%
sns.boxplot(data['Credit Amount'],ax = axes[0,0])
sns.boxplot(data['Duration in month'],ax = axes[0,1])
sns.boxplot(data['Installment rate in % of disposable income'],ax = axes[1,0])
sns.boxplot(data['Present residence since'],ax = axes[1,1])

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (30,30))

# %%
sns.boxplot(data['Age'],ax = axes[0,0])
sns.boxplot(data['Number of dependents'],ax = axes[0,1])
sns.boxplot(data['Number of existing credits'],ax = axes[1,0])
sns.boxplot(data['Credit Rating'],ax = axes[1,1])
plt.show()

# %% [markdown]
# # Building XGBoost model

# %%
import pip

# %%
import sklearn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Imputer
import numpy as np
import scipy.sparse
import pickle
import xgboost 
import scipy

# %%
pip.main(['install','xgboost'])
# Out:
# Collecting xgboost
#   Using cached xgboost-0.7.post3.tar.gz
# No files/directories in C:\Users\tshan\AppData\Local\Temp\pip-build-3eu_txs6\xgboost\pip-egg-info (from PKG-INFO)
# 1

# %%
from xgboost.sklearn import XGBClassifier

# %%
# Selecting the target variable

# %%
y = data['Credit Rating']

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    1
# 3    1
# 4    2
# Name: Credit Rating, dtype: int64

# %%
# selecting predictor variables

# %%
x =  data.drop('Credit Rating', 1)

# %%
x.head()
# Out:
#   Checking Account Status  Duration in month Credit History Purpose  \
# 0                     A11                  6            A34     A43
# 1                     A12                 48            A32     A43
# 2                     A14                 12            A34     A46
# 3                     A11                 42            A32     A42
# 4                     A11                 24            A33     A40
#
#    Credit Amount Savings Account/Bonds Present Employment since  \
# 0           1169                   A65                      A75
# 1           5951                   A61                      A73
# 2           2096                   A61                      A74
# 3           7882                   A61                      A74
# 4           4870                   A61                      A73
#
#    Installment rate in % of disposable income Personal Status Other debtors  \
# 0                                           4             A93          A101
# 1                                           2             A92          A101
# 2                                           2             A93          A101
# 3                                           2             A93          A103
# 4                                           3             A93          A101
#
#    Present residence since Property  Age Other installment plans Housing  \
# 0                        4     A121   67                    A143    A152
# 1                        2     A121   22                    A143    A152
# 2                        3     A121   49                    A143    A152
# 3                        4     A122   45                    A143    A153
# 4                        4     A124   53                    A143    A153
#
#    Number of existing credits Job type  Number of dependents Telephone  \
# 0                           2     A173                     1      A192
# 1                           1     A173                     1      A191
# 2                           1     A172                     2      A191
# 3                           1     A173                     2      A191
# 4                           2     A173                     2      A191
#
#   Foreign worker
# 0           A201
# 1           A201
# 2           A201
# 3           A201
# 4           A201

# %%
# Splitting data into training and testing

# %%
seed = 7
test_size = 0.33
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size,
random_state=seed)

# %%
# converting categorical object data to numeric using one hot encoding

# %%
one_hot_encoded_training_predictors = pd.get_dummies(x_train)
one_hot_encoded_test_predictors = pd.get_dummies(x_test)
final_train, final_test = one_hot_encoded_training_predictors.align(one_hot_encoded_test_predictors,
                                                                    join='left', 
                                                                    axis=1)

# %%
# Model used will be xgboost classifier

# %%
model = XGBClassifier()

# %%
#fit model on training data
# using an early stopping parameter to prevent over fitting

# %%
eval_set = [(final_test, y_test)]

# %%
model.fit(final_train, y_train, early_stopping_rounds=10, eval_metric="logloss",
eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-logloss:0.667562
# Will train until validation_0-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.646547
# [2]	validation_0-logloss:0.629179
# [3]	validation_0-logloss:0.614092
# [4]	validation_0-logloss:0.600973
# [5]	validation_0-logloss:0.587591
# [6]	validation_0-logloss:0.577716
# [7]	validation_0-logloss:0.569991
# [8]	validation_0-logloss:0.563395
# [9]	validation_0-logloss:0.557533
# [10]	validation_0-logloss:0.551033
# [11]	validation_0-logloss:0.545237
# [12]	validation_0-logloss:0.541029
# [13]	validation_0-logloss:0.537736
# [14]	validation_0-logloss:0.533773
# [15]	validation_0-logloss:0.530859
# [16]	validation_0-logloss:0.527688
# [17]	validation_0-logloss:0.52483
# [18]	validation_0-logloss:0.519101
# [19]	validation_0-logloss:0.517221
# [20]	validation_0-logloss:0.51572
# [21]	validation_0-logloss:0.513243
# [22]	validation_0-logloss:0.512029
# [23]	validation_0-logloss:0.51066
# [24]	validation_0-logloss:0.505628
# [25]	validation_0-logloss:0.505003
# [26]	validation_0-logloss:0.502119
# [27]	validation_0-logloss:0.500107
# [28]	validation_0-logloss:0.498576
# [29]	validation_0-logloss:0.497455
# [30]	validation_0-logloss:0.496894
# [31]	validation_0-logloss:0.495493
# [32]	validation_0-logloss:0.494716
# [33]	validation_0-logloss:0.494351
# [34]	validation_0-logloss:0.493323
# [35]	validation_0-logloss:0.490088
# [36]	validation_0-logloss:0.489201
# [37]	validation_0-logloss:0.488228
# [38]	validation_0-logloss:0.48767
# [39]	validation_0-logloss:0.486507
# [40]	validation_0-logloss:0.486469
# [41]	validation_0-logloss:0.48588
# [42]	validation_0-logloss:0.485849
# [43]	validation_0-logloss:0.484079
# [44]	validation_0-logloss:0.483744
# [45]	validation_0-logloss:0.483261
# [46]	validation_0-logloss:0.483164
# [47]	validation_0-logloss:0.48221
# [48]	validation_0-logloss:0.480547
# [49]	validation_0-logloss:0.48042
# [50]	validation_0-logloss:0.479874
# [51]	validation_0-logloss:0.480499
# [52]	validation_0-logloss:0.479356
# [53]	validation_0-logloss:0.479155
# [54]	validation_0-logloss:0.478847
# [55]	validation_0-logloss:0.477996
# [56]	validation_0-logloss:0.477835
# [57]	validation_0-logloss:0.476822
# [58]	validation_0-logloss:0.475871
# [59]	validation_0-logloss:0.476451
# [60]	validation_0-logloss:0.476512
# [61]	validation_0-logloss:0.476717
# [62]	validation_0-logloss:0.476901
# [63]	validation_0-logloss:0.476857
# [64]	validation_0-logloss:0.477143
# [65]	validation_0-logloss:0.477391
# [66]	validation_0-logloss:0.476542
# [67]	validation_0-logloss:0.476354
# [68]	validation_0-logloss:0.476816
# Stopping. Best iteration:
# [58]	validation_0-logloss:0.475871
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
print("Making predictions for the following customers:")
print(final_test.head())
print("The predictions are")
y_predictions = model.predict(final_test.head())
print(y_predictions)
print("The Actual values are")
print(y_test.head())
# Out:
# Making predictions for the following customers:
#      Duration in month  Credit Amount  \
# 778                 36           5711
# 334                 24           4110
# 271                 12           1402
# 802                 20           4272
# 216                 18           3104
#
#      Installment rate in % of disposable income  Present residence since  Age  \
# 778                                           4                        2   38
# 334                                           3                        4   23
# 271                                           3                        4   37
# 802                                           1                        4   24
# 216                                           3                        1   31
#
#      Number of existing credits  Number of dependents  \
# 778                           2                     1
# 334                           2                     2
# 271                           1                     1
# 802                           2                     1
# 216                           1                     1
#
#      Checking Account Status_A11  Checking Account Status_A12  \
# 778                            0                            0
# 334                            1                            0
# 271                            0                            0
# 802                            1                            0
# 216                            1                            0
#
#      Checking Account Status_A13         ...           Housing_A152  \
# 778                            0         ...                      1
# 334                            0         ...                      0
# 271                            0         ...                      0
# 802                            0         ...                      1
# 216                            0         ...                      1
#
#      Housing_A153  Job type_A171  Job type_A172  Job type_A173  Job type_A174  \
# 778             0              0              0              0              1
# 334             0              0              0              1              0
# 271             0              0              0              1              0
# 802             0              0              0              1              0
# 216             0              0              0              1              0
#
#      Telephone_A191  Telephone_A192  Foreign worker_A201  Foreign worker_A202
# 778               0               1                    1                    0
# 334               1               0                    1                    0
# 271               0               1                    1                    0
# 802               1               0                    1                    0
# 216               0               1                    1                    0
#
# [5 rows x 61 columns]
# The predictions are
# [1 2 1 2 1]
# The Actual values are
# 778    1
# 334    2
# 271    1
# 802    1
# 216    1
# Name: Credit Rating, dtype: int64

# %%
# Making prediction on the test data

# %%
y_pred = model.predict(final_test)

# %%
# accuracy score determines performance of the model

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 78.18%

# %%
# using xgboost to plot the important features in the model

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(40,20))
from xgboost import plot_importance
plot_importance(model)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
learning_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]
param_grid = dict(learning_rate=learning_rate)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(model, param_grid, scoring="neg_log_loss", n_jobs=-1, cv=kfold)
grid_result = grid_search.fit(final_train,y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.531115 using {'learning_rate': 0.1}
# -0.690556 (0.000376) with: {'learning_rate': 0.0001}
# -0.668773 (0.003186) with: {'learning_rate': 0.001}
# -0.568070 (0.017990) with: {'learning_rate': 0.01}
# -0.531115 (0.042173) with: {'learning_rate': 0.1}
# -0.569177 (0.053669) with: {'learning_rate': 0.2}
# -0.603345 (0.067882) with: {'learning_rate': 0.3}
