# %% [markdown]
# # Predicting Melbourne Property Prices
# #(Regression,Decision Tree,Random Forest)

# %%
# import libararies needed

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
#Reading in melbourne property data

# %%
melbourne = pd.read_csv("melbourne_housing_full.csv")

# %%
print(melbourne.columns)
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melbourne.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford    68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0      ...            1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council  -37.8014    144.9958
# 1           NaN        NaN  Yarra City Council  -37.7996    144.9984
# 2          79.0     1900.0  Yarra City Council  -37.8079    144.9934
#
#               Regionname Propertycount
# 0  Northern Metropolitan        4019.0
# 1  Northern Metropolitan        4019.0
# 2  Northern Metropolitan        4019.0
#
# [3 rows x 21 columns]

# %%
melbourne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30931 entries, 0 to 30930
# Data columns (total 21 columns):
# Suburb           30931 non-null object
# Address          30931 non-null object
# Rooms            30931 non-null int64
# Type             30931 non-null object
# Price            24197 non-null float64
# Method           30931 non-null object
# SellerG          30931 non-null object
# Date             30931 non-null object
# Distance         30930 non-null float64
# Postcode         30930 non-null float64
# Bedroom2         23868 non-null float64
# Bathroom         23862 non-null float64
# Car              23497 non-null float64
# Landsize         20405 non-null float64
# BuildingArea     12397 non-null float64
# YearBuilt        14109 non-null float64
# CouncilArea      30928 non-null object
# Lattitude        24089 non-null float64
# Longtitude       24089 non-null float64
# Regionname       30928 non-null object
# Propertycount    30928 non-null float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.0+ MB

# %%
melbourne['Date'] = pd.to_datetime(melbourne['Date'])

# %%
melbourne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30931 entries, 0 to 30930
# Data columns (total 21 columns):
# Suburb           30931 non-null object
# Address          30931 non-null object
# Rooms            30931 non-null int64
# Type             30931 non-null object
# Price            24197 non-null float64
# Method           30931 non-null object
# SellerG          30931 non-null object
# Date             30931 non-null datetime64[ns]
# Distance         30930 non-null float64
# Postcode         30930 non-null float64
# Bedroom2         23868 non-null float64
# Bathroom         23862 non-null float64
# Car              23497 non-null float64
# Landsize         20405 non-null float64
# BuildingArea     12397 non-null float64
# YearBuilt        14109 non-null float64
# CouncilArea      30928 non-null object
# Lattitude        24089 non-null float64
# Longtitude       24089 non-null float64
# Regionname       30928 non-null object
# Propertycount    30928 non-null float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(7)
# memory usage: 5.0+ MB

# %%
#split the date column into 3 different columns for day,month and year

# %%
time = melbourne['Date'].iloc[0]
time.month
# Out:
# 3

# %%
melbourne['Month'] = melbourne['Date'].apply(lambda time:time.month)
melbourne['Day'] = melbourne['Date'].apply(lambda time:time.day)
melbourne['Year'] = melbourne['Date'].apply(lambda time:time.year)

# %%
melbourne.head(5)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...   BuildingArea  YearBuilt  \
# 0 2016-03-09       2.5    3067.0  ...            NaN        NaN
# 1 2016-03-12       2.5    3067.0  ...            NaN        NaN
# 2 2016-04-02       2.5    3067.0  ...           79.0     1900.0
# 3 2016-04-02       2.5    3067.0  ...            NaN        NaN
# 4 2017-04-03       2.5    3067.0  ...          150.0     1900.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council   -37.8014    144.9958  Northern Metropolitan
# 1  Yarra City Council   -37.7996    144.9984  Northern Metropolitan
# 2  Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 3  Yarra City Council   -37.8114    145.0116  Northern Metropolitan
# 4  Yarra City Council   -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount  Month  Day  Year
# 0        4019.0      3    9  2016
# 1        4019.0      3   12  2016
# 2        4019.0      4    2  2016
# 3        4019.0      4    2  2016
# 4        4019.0      4    3  2017
#
# [5 rows x 24 columns]

# %% [markdown]
# #Search for missing values

# %%
melbourne.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             6734
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          7063
# Bathroom          7069
# Car               7434
# Landsize         10526
# BuildingArea     18534
# YearBuilt        16822
# CouncilArea          3
# Lattitude         6842
# Longtitude        6842
# Regionname           3
# Propertycount        3
# Month                0
# Day                  0
# Year                 0
# dtype: int64

# %%
# There are a large number of missing values in the dataset
# delete all the rows containing missing values

# %%
melbourne = melbourne.dropna()

# %%
# Check values have been deleted

# %%
melbourne.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# Month            0
# Day              0
# Year             0
# dtype: int64

# %%
melbourne.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  7979.000000  7.979000e+03  7979.000000  7979.000000  7979.000000
# mean      3.057150  1.086061e+06    10.851886  3109.223086     3.034215
# std       0.973962  6.778049e+05     6.596890   105.782719     0.975872
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.360000e+05     6.400000  3044.000000     2.000000
# 50%       3.000000  8.950000e+05     9.800000  3083.000000     3.000000
# 75%       4.000000  1.340000e+06    13.800000  3150.000000     4.000000
# max      12.000000  9.000000e+06    47.400000  3977.000000    12.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  7979.000000  7979.000000   7979.000000   7979.000000  7979.000000
# mean      1.626394     1.661361    514.398546    147.089024  1965.186114
# std       0.724468     0.967962   1009.035470     89.315655    37.185952
# min       1.000000     0.000000      0.000000      0.000000  1196.000000
# 25%       1.000000     1.000000    193.000000     97.000000  1941.000000
# 50%       2.000000     2.000000    460.000000    130.000000  1970.000000
# 75%       2.000000     2.000000    651.000000    177.400000  1999.500000
# max       9.000000    10.000000  40469.000000   3112.000000  2018.000000
#
#          Lattitude   Longtitude  Propertycount        Month          Day  \
# count  7979.000000  7979.000000    7979.000000  7979.000000  7979.000000
# mean    -37.805948   144.991639    7446.293896     7.106655    16.209049
# std       0.087365     0.114408    4378.056558     2.771354     8.076202
# min     -38.174360   144.423790     290.000000     1.000000     1.000000
# 25%     -37.857700   144.922195    4380.000000     5.000000     9.000000
# 50%     -37.799900   144.997810    6543.000000     7.000000    16.000000
# 75%     -37.751600   145.061800   10331.000000     9.000000    24.000000
# max     -37.407200   145.526350   21650.000000    12.000000    30.000000
#
#               Year
# count  7979.000000
# mean   2016.579020
# std       0.524282
# min    2016.000000
# 25%    2016.000000
# 50%    2017.000000
# 75%    2017.000000
# max    2018.000000

# %%
# average number of rooms for  a house is 3 with the largest house having 12
# The largest price obtained was 9 million, a number of large values may skew the data so further insight is needed to decide
# whether median is a more appropriat measure of central tendency
# majority of houses sold where built in 1965 but one from the 12th century
# the minimum value for building area recorded was 0, this may be a data entry error

# %%
melbourne['Rooms'].mode()
# Out:
# 0    3
# dtype: int64

# %%
melbourne[melbourne['Price'] == 9.000000e+06]
# Out:
#          Suburb      Address  Rooms Type      Price Method SellerG       Date  \
# 19583  Mulgrave  35 Bevis St      3    h  9000000.0     PI    Hall 2017-07-29
#
#        Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 19583      18.8    3170.0      ...            1.0  1.0     744.0
#
#        BuildingArea  YearBuilt          CouncilArea Lattitude  Longtitude  \
# 19583         117.0     1960.0  Monash City Council -37.93168   145.16126
#
#                        Regionname Propertycount
# 19583  South-Eastern Metropolitan        7113.0
#
# [1 rows x 21 columns]

# %%
melbourne.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.487934  0.285270  0.081100  0.961309  0.622877
# Price          0.487934  1.000000 -0.205657  0.061956  0.472335  0.474953
# Distance       0.285270 -0.205657  1.000000  0.479290  0.292245  0.119400
# Postcode       0.081100  0.061956  0.479290  1.000000  0.084145  0.104020
# Bedroom2       0.961309  0.472335  0.292245  0.084145  1.000000  0.625669
# Bathroom       0.622877  0.474953  0.119400  0.104020  0.625669  1.000000
# Car            0.408494  0.227116  0.263213  0.056963  0.412741  0.318255
# Landsize       0.101486  0.064463  0.129107  0.068148  0.101259  0.079630
# BuildingArea   0.602239  0.515870  0.138804  0.073040  0.589960  0.547868
# YearBuilt     -0.011853 -0.304945  0.292179  0.075288 -0.001757  0.181605
# Lattitude      0.016505 -0.217723 -0.080343 -0.252083  0.020875 -0.050126
# Longtitude     0.085036  0.210316  0.177938  0.374922  0.084487  0.109211
# Propertycount -0.087170 -0.054848 -0.021836  0.046431 -0.085901 -0.056574
#
#                     Car  Landsize  BuildingArea  YearBuilt  Lattitude  \
# Rooms          0.408494  0.101486      0.602239  -0.011853   0.016505
# Price          0.227116  0.064463      0.515870  -0.304945  -0.217723
# Distance       0.263213  0.129107      0.138804   0.292179  -0.080343
# Postcode       0.056963  0.068148      0.073040   0.075288  -0.252083
# Bedroom2       0.412741  0.101259      0.589960  -0.001757   0.020875
# Bathroom       0.318255  0.079630      0.547868   0.181605  -0.050126
# Car            1.000000  0.143425      0.325277   0.127355   0.009783
# Landsize       0.143425  1.000000      0.085985   0.038110   0.031656
# BuildingArea   0.325277  0.085985      1.000000   0.046333  -0.039581
# YearBuilt      0.127355  0.038110      0.046333   1.000000   0.085734
# Lattitude      0.009783  0.031656     -0.039581   0.085734   1.000000
# Longtitude     0.042155  0.003822      0.099905  -0.016723  -0.359294
# Propertycount -0.033837 -0.026395     -0.063779   0.011209   0.033461
#
#                Longtitude  Propertycount
# Rooms            0.085036      -0.087170
# Price            0.210316      -0.054848
# Distance         0.177938      -0.021836
# Postcode         0.374922       0.046431
# Bedroom2         0.084487      -0.085901
# Bathroom         0.109211      -0.056574
# Car              0.042155      -0.033837
# Landsize         0.003822      -0.026395
# BuildingArea     0.099905      -0.063779
# YearBuilt       -0.016723       0.011209
# Lattitude       -0.359294       0.033461
# Longtitude       1.000000       0.043278
# Propertycount    0.043278       1.000000

# %%
#View the correlation between variables,to give indication of what features to use in the model
#heatmap also displays pearson correlation

# %%
sns.heatmap(melbourne.corr(), annot=True, fmt=".2f")
plt.show()

# %%
print(melbourne.columns)
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
#Numeric and categorical variables in the Dataset

# %%
melbourne.head()
# Out:
#         Suburb          Address  Rooms Type      Price Method SellerG  \
# 2   Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4   Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 6   Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 11  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 14  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#          Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 2  2016-04-02       2.5    3067.0      ...            1.0  0.0     156.0
# 4  2017-04-03       2.5    3067.0      ...            2.0  0.0     134.0
# 6  2016-04-06       2.5    3067.0      ...            1.0  2.0     120.0
# 11 2016-07-05       2.5    3067.0      ...            2.0  0.0     245.0
# 14 2016-08-10       2.5    3067.0      ...            1.0  2.0     256.0
#
#     BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# 2           79.0     1900.0  Yarra City Council  -37.8079    144.9934
# 4          150.0     1900.0  Yarra City Council  -37.8093    144.9944
# 6          142.0     2014.0  Yarra City Council  -37.8072    144.9941
# 11         210.0     1910.0  Yarra City Council  -37.8024    144.9993
# 14         107.0     1890.0  Yarra City Council  -37.8060    144.9954
#
#                Regionname Propertycount
# 2   Northern Metropolitan        4019.0
# 4   Northern Metropolitan        4019.0
# 6   Northern Metropolitan        4019.0
# 11  Northern Metropolitan        4019.0
# 14  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Exploring the categorical variables using boxplots

# %%
sns.boxplot(data = melbourne, x = 'Method', y = 'Price')
plt.show()

# %%
sns.boxplot(data = melbourne, x = 'CouncilArea', y = 'Price')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data = melbourne, x = 'Regionname', y = 'Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Exploing numeric data using scatter matrix

# %%
new_melbourne =['Price','Distance','Bathroom','Propertycount','BuildingArea','Rooms','YearBuilt','Bedroom2','Car']
melbourne1 = (melbourne[new_melbourne])

# %%
sns.pairplot(melbourne1)
plt.show()

# %%
# The data is showing the strongest correlation between price and the number of rooms
# Building Area has also got the strongest correlation with Price

# %%
# their does not appear to be a strong linear relationship between price and other variables

# %%
#Taking a loolk at price closer we see that the boxplot we see that there are some outliers in the Price variable

# %%
print('Mean price paid = £ %d' % np.mean(melbourne['Price']))
print('Median price paid = £ %d' % np.median(melbourne['Price']))
# Out:
# Mean price paid = £ 1086061
# Median price paid = £ 895000

# %%
# becauce the price data contains large outliers there is a large difference between the mean and median
# we will use median as a measure of central tendency

# %% [markdown]
# # Data visualisation

# %%
melbourne['Suburb'].value_counts().head(20).plot.bar()

# %%
sns.countplot(melbourne['Regionname'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="Year",data = melbourne)
plt.title("Properties sold by Year")
plt.show()

# %%
sns.countplot(x="Month",data = melbourne)
plt.title("Properties sold by Month ")
plt.show()

# %%
sns.countplot(x="Day",data = melbourne)
plt.title("Properties sold by Day")
plt.show()

# %%
import seaborn as sns

# %%
melb =['Date','Price']
melbtime = melbourne[melb]
melbtime2 = melbtime.set_index('Date').resample('M')["Price"].median()

# %%
melbtime2.plot()
plt.title("Median Sales by Date")

# %%
Region_avg_price = melbourne.groupby(['Regionname']).median()[['Price']]
Region_avg_price.plot(kind='bar',color='Red',title='Regional Price',fontsize='13')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import interactive
interactive(True)

# %%
melbourne['SellerG'].value_counts().head(30).plot.bar(figsize=(12,6),color='Green')

# %%
melbourne.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 6  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 2 2016-04-02       2.5    3067.0      ...            1.0  0.0     156.0
# 4 2017-04-03       2.5    3067.0      ...            2.0  0.0     134.0
# 6 2016-04-06       2.5    3067.0      ...            1.0  2.0     120.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# 2          79.0     1900.0  Yarra City Council  -37.8079    144.9934
# 4         150.0     1900.0  Yarra City Council  -37.8093    144.9944
# 6         142.0     2014.0  Yarra City Council  -37.8072    144.9941
#
#               Regionname Propertycount
# 2  Northern Metropolitan        4019.0
# 4  Northern Metropolitan        4019.0
# 6  Northern Metropolitan        4019.0
#
# [3 rows x 21 columns]

# %%
rep1 = ['Price','SellerG']
rep = melbourne[rep1]
#rep_plot = rep.groupby("SellerG").sum().head(30).plot.bar(figsize=(12,6),color="Blue")
rep_plot = rep.groupby("SellerG").sum().head(30).sort_values('Price').plot.bar(figsize=(12,6),color="Blue")
plt.title("Median Price by Seller")
plt.show()

# %%
melbourne.head(2)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 2 2016-04-02       2.5    3067.0      ...            1.0  0.0     156.0
# 4 2017-04-03       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# 2          79.0     1900.0  Yarra City Council  -37.8079    144.9934
# 4         150.0     1900.0  Yarra City Council  -37.8093    144.9944
#
#               Regionname Propertycount
# 2  Northern Metropolitan        4019.0
# 4  Northern Metropolitan        4019.0
#
# [2 rows x 21 columns]

# %% [markdown]
# # Regression modelling

# %%
new_melbourne =['BuildingArea','Rooms','Landsize','Distance','Bathroom','Propertycount','Regionname']

# %%
x =(melbourne[new_melbourne])

# %%
print(x.head(5))
# Out:
#     BuildingArea  Rooms  Landsize  Distance  Bathroom  Propertycount  \
# 2           79.0      2     156.0       2.5       1.0         4019.0
# 4          150.0      3     134.0       2.5       2.0         4019.0
# 6          142.0      4     120.0       2.5       1.0         4019.0
# 11         210.0      3     245.0       2.5       2.0         4019.0
# 14         107.0      2     256.0       2.5       1.0         4019.0
#
#                Regionname
# 2   Northern Metropolitan
# 4   Northern Metropolitan
# 6   Northern Metropolitan
# 11  Northern Metropolitan
# 14  Northern Metropolitan

# %%
#Using one Hot encoding to transform Regioname Category to numeric

# %%
x = pd.get_dummies(x, columns=["Regionname"])

# %%
x.head()
# Out:
#     BuildingArea  Rooms  Landsize  Distance  Bathroom  Propertycount  \
# 2           79.0      2     156.0       2.5       1.0         4019.0
# 4          150.0      3     134.0       2.5       2.0         4019.0
# 6          142.0      4     120.0       2.5       1.0         4019.0
# 11         210.0      3     245.0       2.5       2.0         4019.0
# 14         107.0      2     256.0       2.5       1.0         4019.0
#
#     Regionname_Eastern Metropolitan  Regionname_Eastern Victoria  \
# 2                                 0                            0
# 4                                 0                            0
# 6                                 0                            0
# 11                                0                            0
# 14                                0                            0
#
#     Regionname_Northern Metropolitan  Regionname_Northern Victoria  \
# 2                                  1                             0
# 4                                  1                             0
# 6                                  1                             0
# 11                                 1                             0
# 14                                 1                             0
#
#     Regionname_South-Eastern Metropolitan  Regionname_Southern Metropolitan  \
# 2                                       0                                 0
# 4                                       0                                 0
# 6                                       0                                 0
# 11                                      0                                 0
# 14                                      0                                 0
#
#     Regionname_Western Metropolitan  Regionname_Western Victoria
# 2                                 0                            0
# 4                                 0                            0
# 6                                 0                            0
# 11                                0                            0
# 14                                0                            0

# %%
y = melbourne.Price

# %%
y.head()
# Out:
# 2     1035000.0
# 4     1465000.0
# 6     1600000.0
# 11    1876000.0
# 14    1636000.0
# Name: Price, dtype: float64

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.cross_validation

# %%
melbourne_model2 = LinearRegression()

# %%
x_train, x_test, y_train,y_test = sklearn.cross_validation.train_test_split(x, y, test_size = 0.33, random_state = 5)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5345, 14)
# (2634, 14)
# (5345,)
# (2634,)

# %%
melbourne_model2.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Making predictions for the following 5 houses:")
print(x.head())
print("The predictions are")
y_predictions = melbourne_model2.predict(x.head())
print(y_predictions)
# Out:
# Making predictions for the following 5 houses:
#     BuildingArea  Rooms  Landsize  Distance  Bathroom  Propertycount  \
# 2           79.0      2     156.0       2.5       1.0         4019.0
# 4          150.0      3     134.0       2.5       2.0         4019.0
# 6          142.0      4     120.0       2.5       1.0         4019.0
# 11         210.0      3     245.0       2.5       2.0         4019.0
# 14         107.0      2     256.0       2.5       1.0         4019.0
#
#     Regionname_Eastern Metropolitan  Regionname_Eastern Victoria  \
# 2                                 0                            0
# 4                                 0                            0
# 6                                 0                            0
# 11                                0                            0
# 14                                0                            0
#
#     Regionname_Northern Metropolitan  Regionname_Northern Victoria  \
# 2                                  1                             0
# 4                                  1                             0
# 6                                  1                             0
# 11                                 1                             0
# 14                                 1                             0
#
#     Regionname_South-Eastern Metropolitan  Regionname_Southern Metropolitan  \
# 2                                       0                                 0
# 4                                       0                                 0
# 6                                       0                                 0
# 11                                      0                                 0
# 14                                      0                                 0
#
#     Regionname_Western Metropolitan  Regionname_Western Victoria
# 2                                 0                            0
# 4                                 0                            0
# 6                                 0                            0
# 11                                0                            0
# 14                                0                            0
# The predictions are
# [  811880.29201976  1286812.18277841  1434494.13771493  1391209.49440201
#    861658.70280492]

# %%
y_predicts = melbourne_model2.predict(x_test)

# %%
#accuracy of model
#MSE evaluates how much model is out by
mse = sklearn.metrics.mean_squared_error(y_test, y_predicts)
print(mse)
# Out:
# 198908882188.0

# %%
plt.scatter(y_test, y_predicts)
plt.show()
# If the model was a good predictor dots would be around the same point

# %%
# R-squared explains how much the predictors explain variation in the respose variables

# %%
from sklearn import metrics
print('R^2 =',metrics.explained_variance_score(y_test,y_predicts))
# Out:
# R^2 = 0.59044028264

# %%
# just under 60% of variation in y is explained by the model

# %% [markdown]
# # Decison tree model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
melbourne_model = DecisionTreeRegressor()

# %%
from sklearn.model_selection import train_test_split
train_x, val_x, train_y, val_y = train_test_split(x, y,random_state = 0)

# %%
melbourne_model.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
val_predictions = melbourne_model.predict(val_x)

# %%
print("Making predictions for the following 5 houses:")
print(val_x.head())
print("The predictions are")
print(melbourne_model.predict(val_x.head()))
print("Actual values are")
print(val_y.head())
# Out:
# Making predictions for the following 5 houses:
#        BuildingArea  Rooms  Landsize  Distance  Bathroom  Propertycount  \
# 6375          135.0      3     216.0      11.2       2.0         8801.0
# 1645          108.0      3     384.0      13.1       1.0         4605.0
# 20309         163.0      3     697.0      10.4       2.0         3464.0
# 17123         149.0      4     587.0      29.8       2.0         4718.0
# 5729          154.0      3     716.0      12.8       2.0         5629.0
#
#        Regionname_Eastern Metropolitan  Regionname_Eastern Victoria  \
# 6375                                 0                            0
# 1645                                 1                            0
# 20309                                0                            0
# 17123                                0                            0
# 5729                                 0                            0
#
#        Regionname_Northern Metropolitan  Regionname_Northern Victoria  \
# 6375                                  0                             0
# 1645                                  0                             0
# 20309                                 0                             0
# 17123                                 0                             0
# 5729                                  0                             0
#
#        Regionname_South-Eastern Metropolitan  \
# 6375                                       0
# 1645                                       0
# 20309                                      0
# 17123                                      0
# 5729                                       0
#
#        Regionname_Southern Metropolitan  Regionname_Western Metropolitan  \
# 6375                                  1                                0
# 1645                                  0                                0
# 20309                                 0                                1
# 17123                                 0                                0
# 5729                                  0                                1
#
#        Regionname_Western Victoria
# 6375                             0
# 1645                             0
# 20309                            0
# 17123                            1
# 5729                             0
# The predictions are
# [ 1150000.   928000.   950000.   426000.   950000.]
# Actual values are
# 6375     1253000.0
# 1645      948000.0
# 20309    1000001.0
# 17123     347500.0
# 5729      695000.0
# Name: Price, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 251870.970927

# %% [markdown]
# # Random Forest model

# %%
from sklearn.ensemble import RandomForestRegressor

forest_model = RandomForestRegressor()
forest_model.fit(train_x, train_y)
melb_preds = forest_model.predict(val_x)

# %%
print("Making predictions for the following 5 houses:")
print(val_x.head())
print("The predictions are")
print(forest_model.predict(val_x.head()))
print("Actual values are")
print(val_y.head())
# Out:
# Making predictions for the following 5 houses:
#        BuildingArea  Rooms  Landsize  Distance  Bathroom  Propertycount  \
# 6375          135.0      3     216.0      11.2       2.0         8801.0
# 1645          108.0      3     384.0      13.1       1.0         4605.0
# 20309         163.0      3     697.0      10.4       2.0         3464.0
# 17123         149.0      4     587.0      29.8       2.0         4718.0
# 5729          154.0      3     716.0      12.8       2.0         5629.0
#
#        Regionname_Eastern Metropolitan  Regionname_Eastern Victoria  \
# 6375                                 0                            0
# 1645                                 1                            0
# 20309                                0                            0
# 17123                                0                            0
# 5729                                 0                            0
#
#        Regionname_Northern Metropolitan  Regionname_Northern Victoria  \
# 6375                                  0                             0
# 1645                                  0                             0
# 20309                                 0                             0
# 17123                                 0                             0
# 5729                                  0                             0
#
#        Regionname_South-Eastern Metropolitan  \
# 6375                                       0
# 1645                                       0
# 20309                                      0
# 17123                                      0
# 5729                                       0
#
#        Regionname_Southern Metropolitan  Regionname_Western Metropolitan  \
# 6375                                  1                                0
# 1645                                  0                                0
# 20309                                 0                                1
# 17123                                 0                                0
# 5729                                  0                                1
#
#        Regionname_Western Victoria
# 6375                             0
# 1645                             0
# 20309                            0
# 17123                            1
# 5729                             0
# The predictions are
# [ 1150900.   826600.   932050.   429900.   885300.]
# Actual values are
# 6375     1253000.0
# 1645      948000.0
# 20309    1000001.0
# 17123     347500.0
# 5729      695000.0
# Name: Price, dtype: float64

# %%
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 201142.000735

# %% [markdown]
# # The random forest gives us a lower mean_absolute_error and is a better model for predicting prices
